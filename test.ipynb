# %%
import json

with open("SOTABV2forSemTab2023/CTA-SCH-R2/supplementary_files/prototype_embeddingsnomic-embed-text-v2-moe:latest_AVG-False.json", "r") as f:
    data = json.load(f)
third_key = list(data.keys())[79]
print(third_key)
print(data[third_key])
# Out:
# workHours
# ...
